# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",None)

#import pandasql as psql

# %% [markdown]
# # READING TRAIN DATASET

# %%
Trdata=pd.read_csv('/content/drive/MyDrive/intern/credit_train.csv')
Trdata_bk=Trdata.copy()
Trdata.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
#to know information and types of attribute
Trdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %%
# finding column labels
Trdata.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %% [markdown]
# # DEALING WITH DUPLICATE VALUES

# %%
#findig shape of duplicates
Trdata[Trdata.duplicated(keep='last')].shape
# Out:
# (10728, 19)

# %%
#droping duplicates
Trdata.drop_duplicates(inplace=True)

# %%
#checking the count of duplicates
Trdata[Trdata.duplicated(keep='last')].count()
# Out:
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %% [markdown]
# # CHECKING AND DEALING WITH NULL VALUES(TRAIN SET)

# %%
#checking null values
Trdata.isnull().sum()
# Out:
# Loan ID                             1
# Customer ID                         1
# Loan Status                         1
# Current Loan Amount                 1
# Term                                1
# Credit Score                    19155
# Annual Income                   19155
# Years in current job             3803
# Home Ownership                      1
# Purpose                             1
# Monthly Debt                        1
# Years of Credit History             1
# Months since last delinquent    48338
# Number of Open Accounts             1
# Number of Credit Problems           1
# Current Credit Balance              1
# Maximum Open Credit                 3
# Bankruptcies                      191
# Tax Liens                          10
# dtype: int64

# %%
Trdata.shape
# Out:
# (89786, 19)

# %%
#dealing with null values
claims = Trdata.fillna(method='ffill',limit =1)
claims.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term         709.0      1167493.0
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term         721.0       806949.0
#
# ...

# %%
#checking the null values number
claims.isnull().sum()
# Out:
# Loan ID                             0
# Customer ID                         0
# Loan Status                         0
# Current Loan Amount                 0
# Term                                0
# Credit Score                     4121
# Annual Income                    4121
# Years in current job              164
# Home Ownership                      0
# Purpose                             0
# Monthly Debt                        0
# Years of Credit History             0
# Months since last delinquent    26096
# Number of Open Accounts             0
# Number of Credit Problems           0
# Current Credit Balance              0
# Maximum Open Credit                 0
# Bankruptcies                        0
# Tax Liens                           0
# dtype: int64

# %%
#information aboout te dataset
claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89786 entries, 0 to 100000
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan ID                       89786 non-null  object
#  1   Customer ID                   89786 non-null  object
#  2   Loan Status                   89786 non-null  object
#  3   Current Loan Amount           89786 non-null  float64
#  4   Term                          89786 non-null  object
#  5   Credit Score                  85665 non-null  float64
#  6   Annual Income                 85665 non-null  float64
#  7   Years in current job          89622 non-null  object
#  8   Home Ownership                89786 non-null  object
#  9   Purpose                       89786 non-null  object
#  10  Monthly Debt                  89786 non-null  float64
#  11  Years of Credit History       89786 non-null  float64
# ...

# %%
# claims = Trdata.fillna(method='bfill')
# claims.head()

# %%
#interpolating method to deal with missing values
claims = claims.interpolate(method ='linear',limit_direction = 'forward')
claims
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 99996   06eba04f-58fc-424a-b666-ed72aa008900
# 99997   e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
# 99998   81ab928b-d1a5-4523-9a3c-271ebb01b4fb
# 99999   c63916c6-6d46-47a9-949a-51d09af4414f
# 100000  c63916c6-6d46-47a9-949a-51d09af4414f
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
#droping null values
claims.dropna(inplace = True)

# %%
#checking the null values number
claims.isnull().sum()
# Out:
# Loan ID                         0
# Customer ID                     0
# Loan Status                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %% [markdown]
# # ENCODING (TRAIN SET)

# %%
#using label encoding to convert  objects to strings
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cols=['Loan Status','Term','Years in current job','Home Ownership','Purpose']
for i in cols:
  claims[i]=le.fit_transform(claims[i])

# %%
#checking dataset information results after type conversion
claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89621 entries, 1 to 99999
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan ID                       89621 non-null  object
#  1   Customer ID                   89621 non-null  object
#  2   Loan Status                   89621 non-null  int64
#  3   Current Loan Amount           89621 non-null  float64
#  4   Term                          89621 non-null  int64
#  5   Credit Score                  89621 non-null  float64
#  6   Annual Income                 89621 non-null  float64
#  7   Years in current job          89621 non-null  int64
#  8   Home Ownership                89621 non-null  int64
#  9   Purpose                       89621 non-null  int64
#  10  Monthly Debt                  89621 non-null  float64
#  11  Years of Credit History       89621 non-null  float64
# ...

# %% [markdown]
# # FOR TEST CASE

# %%
#raeding test data set
tsdata=pd.read_csv('/content/drive/MyDrive/intern/credit_test.csv')
tsdata_bk=tsdata.copy()
tsdata.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  f738779f-c726-40dc-92cf-689d73af533d  ded0b3c3-6bf4-4091-8726-47039f2c1b90
# 1  6dcc0947-164d-476c-a1de-3ae7283dde0a  1630e6e3-34e3-461a-8fda-09297d3140c8
# 2  f7744d01-894b-49c3-8777-fc6431a2cff1  2c60938b-ad2b-4702-804d-eeca43949c52
# 3  83721ffb-b99a-4a0f-aea5-ef472a138b41  12116614-2f3c-4d16-ad34-d92883718806
# 4  08f3789f-5714-4b10-929d-e1527ab5e5a3  39888105-fd5f-4023-860a-30a3e6f5ccb7
#
#    Current Loan Amount        Term  Credit Score  Annual Income  \
# 0             611314.0  Short Term         747.0      2074116.0
# 1             266662.0  Short Term         734.0      1919190.0
# 2             153494.0  Short Term         709.0       871112.0
# 3             176242.0  Short Term         727.0       780083.0
# 4             321992.0  Short Term         744.0      1761148.0
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# ...

# %%
#infotion of datatypes of test data
tsdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10353 entries, 0 to 10352
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan ID                       10000 non-null  object
#  1   Customer ID                   10000 non-null  object
#  2   Current Loan Amount           10000 non-null  float64
#  3   Term                          10000 non-null  object
#  4   Credit Score                  8019 non-null   float64
#  5   Annual Income                 8019 non-null   float64
#  6   Years in current job          9573 non-null   object
#  7   Home Ownership                10000 non-null  object
#  8   Purpose                       10000 non-null  object
#  9   Monthly Debt                  10000 non-null  float64
#  10  Years of Credit History       10000 non-null  float64
#  11  Months since last delinquent  4694 non-null   float64
# ...

# %% [markdown]
# # CHECKING DUPLICATE VALUES(TEST DATASET)

# %%
#checking duplicates
tsdata[tsdata.duplicated(keep='last')].count()
# Out:
# Loan ID                         0
# Customer ID                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %% [markdown]
# # CHECKING AND DEALING WITH NULL VALUES (TEST DATASET)

# %%
#checking the null values number
tsdata.isnull().sum()
# Out:
# Loan ID                          353
# Customer ID                      353
# Current Loan Amount              353
# Term                             353
# Credit Score                    2334
# Annual Income                   2334
# Years in current job             780
# Home Ownership                   353
# Purpose                          353
# Monthly Debt                     353
# Years of Credit History          353
# Months since last delinquent    5659
# Number of Open Accounts          353
# Number of Credit Problems        353
# Current Credit Balance           353
# Maximum Open Credit              353
# Bankruptcies                     375
# Tax Liens                        354
# dtype: int64

# %%
#dealing with null vaues by front forword method
tsdata.fillna(method='ffill',axis=1)
# Out:
#                                     Loan ID  \
# 0      f738779f-c726-40dc-92cf-689d73af533d
# 1      6dcc0947-164d-476c-a1de-3ae7283dde0a
# 2      f7744d01-894b-49c3-8777-fc6431a2cff1
# 3      83721ffb-b99a-4a0f-aea5-ef472a138b41
# 4      08f3789f-5714-4b10-929d-e1527ab5e5a3
# ...                                     ...
# 10348                                   NaN
# 10349                                   NaN
# 10350                                   NaN
# 10351                                   NaN
# 10352                                   NaN
#
#                                 Customer ID Current Loan Amount        Term  \
# 0      ded0b3c3-6bf4-4091-8726-47039f2c1b90            611314.0  Short Term
# 1      1630e6e3-34e3-461a-8fda-09297d3140c8            266662.0  Short Term
# 2      2c60938b-ad2b-4702-804d-eeca43949c52            153494.0  Short Term
# 3      12116614-2f3c-4d16-ad34-d92883718806            176242.0  Short Term
# ...

# %%
#dealing with backword method on missing values
tsdata.fillna(method='bfill',axis=1)
# Out:
#                                     Loan ID  \
# 0      f738779f-c726-40dc-92cf-689d73af533d
# 1      6dcc0947-164d-476c-a1de-3ae7283dde0a
# 2      f7744d01-894b-49c3-8777-fc6431a2cff1
# 3      83721ffb-b99a-4a0f-aea5-ef472a138b41
# 4      08f3789f-5714-4b10-929d-e1527ab5e5a3
# ...                                     ...
# 10348                                   NaN
# 10349                                   NaN
# 10350                                   NaN
# 10351                                   NaN
# 10352                                   NaN
#
#                                 Customer ID Current Loan Amount        Term  \
# 0      ded0b3c3-6bf4-4091-8726-47039f2c1b90            611314.0  Short Term
# 1      1630e6e3-34e3-461a-8fda-09297d3140c8            266662.0  Short Term
# 2      2c60938b-ad2b-4702-804d-eeca43949c52            153494.0  Short Term
# 3      12116614-2f3c-4d16-ad34-d92883718806            176242.0  Short Term
# ...

# %%
claims1 = tsdata.fillna(value=tsdata.mean())

# %%
#dealing with interpolation  method on missing values
claims1 = claims1.interpolate(method ='linear',limit_direction = 'forward')
claims1
# Out:
#                                     Loan ID  \
# 0      f738779f-c726-40dc-92cf-689d73af533d
# 1      6dcc0947-164d-476c-a1de-3ae7283dde0a
# 2      f7744d01-894b-49c3-8777-fc6431a2cff1
# 3      83721ffb-b99a-4a0f-aea5-ef472a138b41
# 4      08f3789f-5714-4b10-929d-e1527ab5e5a3
# ...                                     ...
# 10348                                   NaN
# 10349                                   NaN
# 10350                                   NaN
# 10351                                   NaN
# 10352                                   NaN
#
#                                 Customer ID  Current Loan Amount        Term  \
# 0      ded0b3c3-6bf4-4091-8726-47039f2c1b90         6.113140e+05  Short Term
# 1      1630e6e3-34e3-461a-8fda-09297d3140c8         2.666620e+05  Short Term
# 2      2c60938b-ad2b-4702-804d-eeca43949c52         1.534940e+05  Short Term
# 3      12116614-2f3c-4d16-ad34-d92883718806         1.762420e+05  Short Term
# ...

# %%
claims2=claims1.fillna(claims1.mode().iloc[0])

# %%
#checking null values count after applying te methods
claims2.isnull().sum()
# Out:
# Loan ID                         0
# Customer ID                     0
# Current Loan Amount             0
# Term                            0
# Credit Score                    0
# Annual Income                   0
# Years in current job            0
# Home Ownership                  0
# Purpose                         0
# Monthly Debt                    0
# Years of Credit History         0
# Months since last delinquent    0
# Number of Open Accounts         0
# Number of Credit Problems       0
# Current Credit Balance          0
# Maximum Open Credit             0
# Bankruptcies                    0
# Tax Liens                       0
# dtype: int64

# %% [markdown]
# # ENCODING TECHNIQUES

# %%
#converting objects to int
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cols1=['Term','Years in current job','Home Ownership','Purpose']
for i in cols1:
  claims2[i]=le.fit_transform(claims2[i])

# %%
#checking dtaaest info after encoding
claims2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10353 entries, 0 to 10352
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Loan ID                       10353 non-null  object
#  1   Customer ID                   10353 non-null  object
#  2   Current Loan Amount           10353 non-null  float64
#  3   Term                          10353 non-null  int64
#  4   Credit Score                  10353 non-null  float64
#  5   Annual Income                 10353 non-null  float64
#  6   Years in current job          10353 non-null  int64
#  7   Home Ownership                10353 non-null  int64
#  8   Purpose                       10353 non-null  int64
#  9   Monthly Debt                  10353 non-null  float64
#  10  Years of Credit History       10353 non-null  float64
#  11  Months since last delinquent  10353 non-null  float64
# ...

# %%
#deleting unwanted values
del claims2['Loan ID']
del claims2['Customer ID']

# %% [markdown]
# # TARGET VARIABLE ANALYSIS

# %%
claims.nunique()
# Out:
# Loan ID                         81854
# Customer ID                     81854
# Loan Status                         2
# Current Loan Amount             21987
# Term                                2
# Credit Score                     1140
# Annual Income                   39605
# Years in current job               11
# Home Ownership                      4
# Purpose                            16
# Monthly Debt                    65680
# Years of Credit History           506
# Months since last delinquent     2512
# Number of Open Accounts            51
# Number of Credit Problems          14
# Current Credit Balance          32714
# Maximum Open Credit             44559
# Bankruptcies                        8
# Tax Liens                          12
# dtype: int64

# %%
# x_train = claims.drop('Loan Status',axis=1).values
# y_train = claims['Loan Status'].values
# x_test = claims2.values

# %%
claims['Loan Status'].value_counts()
# Out:
# 1    67043
# 0    22578
# Name: Loan Status, dtype: int64

# %%
del claims['Loan ID']
del claims['Customer ID']

# %% [markdown]
# # CHECKING THE BALANCE OF DATASET

# %%
#checking balance ratio of dataset
Loan_Status_count=claims['Loan Status'].value_counts()
print('class 0',Loan_Status_count[0])
print('class 1',Loan_Status_count[1])
print('Proportion:', round(Loan_Status_count[0] / Loan_Status_count[1], 2), ': 1')
print('Total records:', len(claims))
# Out:
# class 0 22578
# class 1 67043
# Proportion: 0.34 : 1
# Total records: 89621

# %% [markdown]
# # DEFINING DEPENDENT AND INDEPENDENT VAIRABLES

# %%
#separation of dependent and independent variables
IndepVar=[]
for col in claims.columns:
    if col!='Loan Status':
        IndepVar.append(col)

TargetVar='Loan Status'
x=claims[IndepVar]
y=claims[TargetVar]

# %% [markdown]
# # SPLITTING INTO TRAIN AND TEST

# %%
#spletting test and train dataset
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Display the shape for train & test data

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((62734, 16), (26887, 16), (62734,), (26887,))

# %%
#applying minmax scalar function
from sklearn.preprocessing import MinMaxScaler

mmscaler = MinMaxScaler(feature_range=(0, 1))

x_train = mmscaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train)

x_test = mmscaler.fit_transform(x_test)
x_test = pd.DataFrame(x_test)

# %% [markdown]
# # KNN AND SVM

# %%
#loading the results file for svm
EMResults1=pd.read_csv(r"/content/drive/MyDrive/intern/EMResults.csv",header=0)
EMResults1.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build KNN Model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):

    k = a

    # Build the model

    ModelKNN = KNeighborsClassifier(n_neighbors=k)

    # Train the model

    ModelKNN.fit(x_train, y_train)

    # Predict the model

    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)

    print('KNN_K_value = ', a)

    # Print the model name

    print('Model Name: ', ModelKNN)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults2 = EMResults2.append(new_row, ignore_index=True)
    #------KNN_Results------------------------------------------------------------------------
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[16239  3930]
#  [ 4073  2645]]
# Outcome values :
#  16239 3930 4073 2645
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.80      0.81      0.80     20169
#            0       0.40      0.39      0.40      6718
#
#     accuracy                           0.70     26887
#    macro avg       0.60      0.60      0.60     26887
# weighted avg       0.70      0.70      0.70     26887
#
# Accuracy : 70.2 %
# Precision : 79.9 %
# Recall : 80.5 %
# F1 Score : 0.802
# Specificity or True Negative Rate : 39.4 %
# Balanced Accuracy : 60.0 %
# MCC : 0.2
# roc_auc_score: 0.599
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[13426  6743]
#  [ 3020  3698]]
# Outcome values :
#  13426 6743 3020 3698
# Classification report :
#                precision    recall  f1-score   support
#
# ...

# %%
EMResults2
# Out:
#                               Model Name True_Positive False_Negative  \
# 0    KNeighborsClassifier(n_neighbors=1)         16239           3930
# 1    KNeighborsClassifier(n_neighbors=2)         13426           6743
# 2    KNeighborsClassifier(n_neighbors=3)         17640           2529
# 3    KNeighborsClassifier(n_neighbors=4)         16124           4045
# 4                 KNeighborsClassifier()         18445           1724
# 5    KNeighborsClassifier(n_neighbors=6)         17465           2704
# 6    KNeighborsClassifier(n_neighbors=7)         18846           1323
# 7    KNeighborsClassifier(n_neighbors=8)         18211           1958
# 8    KNeighborsClassifier(n_neighbors=9)         19104           1065
# 9   KNeighborsClassifier(n_neighbors=10)         18673           1496
# 10  KNeighborsClassifier(n_neighbors=11)         19273            896
# 11  KNeighborsClassifier(n_neighbors=12)         18945           1224
# ...

# %%
#loading the results file for svm
EMResults2=pd.read_csv(r"/content/drive/MyDrive/intern/EMResults.csv",header=0)
EMResults2.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
from sklearn.svm import SVC
#linear kernal
ModelSVM1 = SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True,
                probability=True, tol=0.001, cache_size=200, class_weight=None, verbose=False,
                max_iter=- 1, decision_function_shape='ovr', break_ties=False, random_state=None)
#polynomial kernal
ModelSVMPoly = SVC(kernel='poly', degree=2, probability=True)
#guassian kernal
ModelSVMGaussian = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)
#sigmoid kernal
ModelSVMSig = SVC(kernel='sigmoid', random_state = 42, class_weight='balanced', probability=True)
svcm=[ModelSVM1,ModelSVMPoly,ModelSVMGaussian,ModelSVMSig]

for models in svcm:

    # Train the model training dataset

    models.fit(x_train, y_train)

    # Prediction the model with test dataset

    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)

    # Print the model name

    print('Model Name: ', models)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    Model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    #
    plt.plot(fpr, tpr, label= 'Classification Model' % Model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive': tp,
               'False_Negative': fn,
               'False_Positive': fp,
               'True_Negative': tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults1 = EMResults1.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
#======================================================================================================================>
# Out:
# Model Name:  SVC(kernel='linear', probability=True)
# Confusion matrix :
#  [[19913   256]
#  [ 5262  1456]]
# Outcome values :
#  19913 256 5262 1456
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.79      0.99      0.88     20169
#            0       0.85      0.22      0.35      6718
#
#     accuracy                           0.79     26887
#    macro avg       0.82      0.60      0.61     26887
# weighted avg       0.81      0.79      0.75     26887
#
# Accuracy : 79.5 %
# Precision : 79.1 %
# Recall : 98.7 %
# F1 Score : 0.878
# Specificity or True Negative Rate : 21.7 %
# Balanced Accuracy : 60.2 %
# MCC : 0.362
# roc_auc_score: 0.602
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(degree=2, kernel='poly', probability=True)
# Confusion matrix :
#  [[19963   206]
#  [ 5282  1436]]
# Outcome values :
#  19963 206 5282 1436
# ...

# %%
EMResults1
# Out:
#                                            Model Name True_Positive  \
# 0                 KNeighborsClassifier(n_neighbors=1)         16239
# 1                 KNeighborsClassifier(n_neighbors=2)         13426
# 2                 KNeighborsClassifier(n_neighbors=3)         17640
# 3                 KNeighborsClassifier(n_neighbors=4)         16124
# 4                              KNeighborsClassifier()         18445
# 5                 KNeighborsClassifier(n_neighbors=6)         17465
# 6                 KNeighborsClassifier(n_neighbors=7)         18846
# 7                 KNeighborsClassifier(n_neighbors=8)         18211
# 8                 KNeighborsClassifier(n_neighbors=9)         19104
# 9                KNeighborsClassifier(n_neighbors=10)         18673
# 10               KNeighborsClassifier(n_neighbors=11)         19273
# 11               KNeighborsClassifier(n_neighbors=12)         18945
# 12               KNeighborsClassifier(n_neighbors=13)         19420
# ...

# %% [markdown]
# # EMR

# %% [markdown]
# # CLASSIFICATION MODELS

# %%
#loading the results file for svm
EMResults=pd.read_csv(r"/content/drive/MyDrive/intern/EMResults.csv",header=0)
EMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# Create objects of classification algorithm with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=19)
ModelSVM = SVC(kernel='poly', degree=2, probability=True)

ModelGNB = GaussianNB()

# Evalution matrix for all the algorithms

MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelSVM, ModelGNB]
for models in MM:

    # Fit the model

    models.fit(x_train, y_train)

    # Prediction

    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)

    # Print the model name

    print('Model Name: ', models)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    logit_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,


               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults = EMResults.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[19927   242]
#  [ 5261  1457]]
# Outcome values :
#  19927 242 5261 1457
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.79      0.99      0.88     20169
#            0       0.86      0.22      0.35      6718
#
#     accuracy                           0.80     26887
#    macro avg       0.82      0.60      0.61     26887
# weighted avg       0.81      0.80      0.75     26887
#
# Accuracy : 79.5 %
# Precision : 79.1 %
# Recall : 98.8 %
# F1 Score : 0.879
# Specificity or True Negative Rate : 21.7 %
# Balanced Accuracy : 60.2 %
# MCC : 0.365
# roc_auc_score: 0.602
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[14189  5980]
#  [ 4223  2495]]
# Outcome values :
#  14189 5980 4223 2495
# Classification report :
# ...

# %% [markdown]
# # COMPARESION

# %%
EMResults.head()
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()         19927
# 1                           DecisionTreeClassifier()         14125
# 2  (DecisionTreeClassifier(max_features='sqrt', r...         19607
# 3  (ExtraTreeClassifier(random_state=1219024987),...         19869
# 4                             KNeighborsClassifier()         18445
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0            242           5261          1457     0.795      0.791   0.988
# 1           6044           4152          2566     0.621      0.773   0.700
# 2            562           5110          1608     0.789      0.793   0.972
# 3            300           5244          1474     0.794      0.791   0.985
# 4           1724           4633          2085     0.764      0.799   0.915
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# ...

# %% [markdown]
# # RESULT

# %%
#PREDICTING TARGET VARIABLE FOR train DATA
y_prednv = ModelLR.predict(x_test)

# %%
Results = pd.DataFrame({'Loan Status_A' : y_test,'Loan Status_P':y_prednv})

ResultsFinal = claims.merge(Results,left_index =True,right_index= True)
ResultsFinal.sample(10)
# Out:
#        Loan Status  Current Loan Amount  Term  Credit Score  Annual Income  \
# 56519            0             635734.0     1         706.0      1448655.0
# 92499            1           99999999.0     1         743.0       758784.0
# 89761            1           99999999.0     0         690.0       937270.0
# 18785            1             437756.0     0         707.0      2022626.0
# 14774            1           99999999.0     1         737.0      1122444.0
# 40450            1             222332.0     1         736.0       570313.5
# 48833            1           99999999.0     1         742.0      1515288.0
# 32369            0             265496.0     0         741.0       983155.0
# 88985            1             401940.0     1         615.0      2853135.0
# 50033            0             525470.0     0         721.0      1512704.0
#
#        Years in current job  Home Ownership  Purpose  Monthly Debt  \
# 56519                     7               1        3      33801.95
# ...

# %%
# Calculate the %of Error

ResultsFinal['%Error'] = round(((ResultsFinal['Loan Status_A']-ResultsFinal['Loan Status_P'])/ResultsFinal['Loan Status_A'])*100,3)

# %%
ResultsFinal.sample(10)
# Out:
#        Loan Status  Current Loan Amount  Term  Credit Score  Annual Income  \
# 68489            1             584254.0     0         724.0      1126681.0
# 5959             1             771386.0     1         730.0      1865344.0
# 95865            0             449768.0     1         695.0      1650853.0
# 69821            1             313676.0     1         751.0      1702761.0
# 8246             1             735416.0     1         748.0       992940.0
# 85571            1             125884.0     1         744.0      1977330.0
# 51445            1             760298.0     1         733.0      8629876.0
# 50019            1           99999999.0     1         729.0      1421162.0
# 74248            1           99999999.0     0         626.0       836855.0
# 36124            1             216458.0     1         693.0       957562.0
#
#        Years in current job  Home Ownership  Purpose  Monthly Debt  \
# 68489                     1               1        3      26101.63
# ...

# %% [markdown]
# # PREDICTING TARGET VARIABLE FOR TEST DATA

# %%
#PREDICTING TARGET VARIABLE FOR TEST DATA
prednv = ModelLR.predict(claims2)

# %%
#result nad the samples
Results1 = pd.DataFrame({'Loan Status_P':prednv})

ResultsFinal1 = claims2.merge(Results1,left_index =True,right_index= True)
ResultsFinal1.sample(10)
# Out:
#        Current Loan Amount  Term  Credit Score  Annual Income  \
# 7614          1.000000e+08     1     709.00000   4.491258e+06
# 5982          3.312980e+05     1     693.00000   1.059744e+06
# 9146          1.951180e+05     1    7270.00000   1.405012e+06
# 2819          6.212360e+05     0     636.00000   3.081059e+06
# 1333          1.111440e+05     1     726.00000   3.639450e+05
# 8899          8.916600e+04     1    1077.99152   1.369106e+06
# 7599          3.657500e+05     1     707.00000   9.304300e+05
# 10242         1.160380e+07     1    1077.99152   1.369106e+06
# 9233          2.600180e+05     1    1077.99152   1.369106e+06
# 1907          1.000000e+08     1     726.00000   1.221415e+06
#
#        Years in current job  Home Ownership  Purpose  Monthly Debt  \
# 7614                      1               3        0  19013.110000
# 5982                      5               1        3  19251.940000
# 9146                      5               3        7   4976.100000
# ...
